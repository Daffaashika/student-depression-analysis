# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ba996b60-1181-4b74-a259-cfe1f941df1c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ba996b60-1181-4b74-a259-cfe1f941df1c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# Baca file
df = pd.read_csv('dataset.csv')

# Lihat 5 baris pertama
df.head()
# Out:
#   What is your age group?    What is your occupation?  Where do you live?   \
# 0                    18-25                     Student          Urban Area
# 1                    18-25                     Student          Urban Area
# 2                    18-25                     Student          Urban Area
# 3                    18-25                     Student          Urban Area
# 4                    18-25                     Student       Suburban Area
#
#   How many hours per day do you spend on social media?   \
# 0                                  More than 5 hours
# 1                                          3-5 hours
# 2                                          3-5 hours
# 3                                          3-5 hours
# 4                                          3-5 hours
#
#   How has social media affected your real-life relationships?   \
# 0                                           Improved
# 1                                          No Change
# ...

# %%
# Ukuran data
print("Jumlah baris dan kolom:", df.shape)

# Cek tipe data & missing value
df.info()

# Cek ringkasan statistik
df.describe()
# Out:
# Jumlah baris dan kolom: (49, 10)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 10 columns):
#  #   Column                                                        Non-Null Count  Dtype
# ---  ------                                                        --------------  -----
#  0   What is your age group?                                       49 non-null     object
#  1     What is your occupation?                                    49 non-null     object
#  2   Where do you live?                                            49 non-null     object
#  3   How many hours per day do you spend on social media?          49 non-null     object
#  4   How has social media affected your real-life relationships?   49 non-null     object
#  5   How frequently do you use email for communication?            49 non-null     object
#  6   Do you use LinkedIn for professional networking?              49 non-null     object
# ...

# %%
print(df.columns)
# Out:
# Index(['what_is_your_age_group?', 'what_is_your_occupation?',
#        'where_do_you_live?',
#        'how_many_hours_per_day_do_you_spend_on_social_media?',
#        'how_has_social_media_affected_your_real-life_relationships?',
#        'how_frequently_do_you_use_email_for_communication?',
#        'do_you_use_linkedin_for_professional_networking?',
#        'how_often_do_you_use_whatsapp_for_communication?',
#        'which_social_media_platforms_do_you_use_the_most?',
#        'do_you_feel_that_social_media_affects_your_mental_health?'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# what_is_your_age_group?                                        0
# what_is_your_occupation?                                       0
# where_do_you_live?                                             0
# how_many_hours_per_day_do_you_spend_on_social_media?           0
# how_has_social_media_affected_your_real-life_relationships?    0
# how_frequently_do_you_use_email_for_communication?             0
# do_you_use_linkedin_for_professional_networking?               0
# how_often_do_you_use_whatsapp_for_communication?               0
# which_social_media_platforms_do_you_use_the_most?              0
# do_you_feel_that_social_media_affects_your_mental_health?      0
# dtype: int64

# %%
sns.countplot(x='do_you_feel_that_social_media_affects_your_mental_health?', data=df)
plt.title("Apakah Media Sosial Mempengaruhi Kesehatan Mental?")
plt.xticks(rotation=45)
plt.show()

# %%
sns.boxplot(
    x='do_you_feel_that_social_media_affects_your_mental_health?',
    y='how_many_hours_per_day_do_you_spend_on_social_media?',
    data=df
)
plt.title("Durasi Media Sosial vs Dampak ke Kesehatan Mental")
plt.xticks(rotation=45)
plt.show()

# %%
File > Download > Download .ipynb
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-f70b755cdc25> in <cell line: 0>()
# ----> 1 File > Download > Download .ipynb
#
# NameError: name 'File' is not defined

# %%
df.to_csv('cleaned_data.csv', index=False)
files.download('cleaned_data.csv')
